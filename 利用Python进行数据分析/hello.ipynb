# %%
import numpy as np
a = np.random.randn(100, 100)

# %%
np.dot(a, a)
# Out:
# array([[ -0.22254057,   3.71185337,   6.2018972 , ...,   6.95999753,
#          -2.7351853 ,  15.14173564],
#        [ -0.97939671,   8.48636328,  -2.49934344, ...,  -2.40645888,
#          -5.10244823,   5.48447938],
#        [ 10.09104138, -11.37538027,  15.24617907, ...,   1.81255382,
#          10.25787532,  -1.71509199],
#        ...,
#        [ 10.34871491,   7.19650517,  14.79680117, ...,  -5.72151726,
#          10.79301598,   1.59829892],
#        [-13.95334457,   4.14336501,   2.99831273, ...,  12.72937603,
#           8.25266223,  14.97815655],
#        [ 11.85271112,  -5.318444  ,  -5.55187781, ...,   0.71312689,
#         -12.61676346,  -0.48908937]])

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.plot(np.random.randn(50).cumsum())
